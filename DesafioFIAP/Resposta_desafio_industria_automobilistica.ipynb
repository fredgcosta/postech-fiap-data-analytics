# %% [markdown]
# **Data Analytics Challenge - 2DTAT** 📊
#
# Olá  Estudante!
# Seja muito bem-vindo ao seu desafio de Data Analytics!
#
# Seu desafio está em resolver o seguinte problema:
#
# Você enquanto analista de dados de uma empresa, recebeu a missão de fazer uma análise exploratória (EDA) para que você gerasse insights relevantes na industria automobilística. 🚔
#
# Como treino, você recebeu o Auto MPG Data Set com informações relevantes do consumo de milhas por galão de determinados automóveis.
#
# A descrição das colunas do dataset pode ser encontrada aqui.
#
# Através desses dados, você terá que responder 20 perguntas de múltipla escolha abaixo, que envolvem : análise exploratória, programação e estatística.
#
# OBS: Nem todas as perguntas são sobre dataset em si, pode ocorrer questões mais teóricas envolvendo conceitos fundamentais de análise exploratória, programação e estatística

# %% [markdown]
# 3 - Se quisermos carregar o dataset via python, precisaremos da biblioteca "pandas". Qual a sintaxe correta para essa ação?

# %%
import pandas as pd

df = pd.read_csv("auto-mpg-original.csv", sep=";")

df.head()
# Out:
#      mpg cylinders displacement horsepower   weight acceleration model year  \
# 0  18,00      8,00       307,00     130,00  3504,00        12,00      70,00
# 1  15,00      8,00       350,00     165,00  3693,00        11,50      70,00
# 2  18,00      8,00       318,00     150,00  3436,00        11,00      70,00
# 3  16,00      8,00       304,00     150,00  3433,00        12,00      70,00
# 4  17,00      8,00       302,00     140,00  3449,00        10,50      70,00
#
#   origin                   car name
# 0   1,00  chevrolet chevelle malibu
# 1   1,00          buick skylark 320
# 2   1,00         plymouth satellite
# 3   1,00              amc rebel sst
# 4   1,00                ford torino

# %% [markdown]
# 1 - Qual a dimensão do dataset inicialmente em (linhas, colunas)

# %%
df.shape
# Out:
# (406, 9)

# %% [markdown]
# 2 - Em uma análise de dados, é muito comum fazermos as limpezas dos valores nulos para que consigamos analisar principalmente dados numéricos, onde podemos substituir os valores nulos por algum valor que deixe os dados mais próximos da realidade, ou simplesmente excluir as linhas onde eles estão. Se optarmos excluir as linhas com valores nulos em qualquer coluna para que possamos, nosso dataset passará a ter quantas linhas?
#
# 13 - Os valores nulos dentro de um conjuto de dados sempre atrapalham na visualização e na compreensão das nossas análises. Qual função do pandas identifica que há dados nulos no dataset?

# %%
df.isnull()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 401  False      False         False       False   False         False
# 402  False      False         False       False   False         False
# 403  False      False         False       False   False         False
# 404  False      False         False       False   False         False
# 405  False      False         False       False   False         False
#
#      model year  origin  car name
# 0         False   False     False
# 1         False   False     False
# ...

# %%
df.isnull().sum()
# Out:
# mpg             8
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.dropna(axis=0, how='any', inplace=True)

# %%
df.shape
# Out:
# (392, 9)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %% [markdown]
#  4 - Olhando para o ano de fabricação, qual ano corresponde a carros com maior economia de milhas por galão (mpg) ?
#
#  12 - Quando montamos um gráfico para comparar qual o ano dos carros apresentaram uma maior economia no mpg, qual ano mostrou o maior desempenho?

# %%
df.head()
# Out:
#      mpg cylinders displacement horsepower   weight acceleration model year  \
# 0  18,00      8,00       307,00     130,00  3504,00        12,00      70,00
# 1  15,00      8,00       350,00     165,00  3693,00        11,50      70,00
# 2  18,00      8,00       318,00     150,00  3436,00        11,00      70,00
# 3  16,00      8,00       304,00     150,00  3433,00        12,00      70,00
# 4  17,00      8,00       302,00     140,00  3449,00        10,50      70,00
#
#   origin                   car name
# 0   1,00  chevrolet chevelle malibu
# 1   1,00          buick skylark 320
# 2   1,00         plymouth satellite
# 3   1,00              amc rebel sst
# 4   1,00                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    object
#  1   cylinders     392 non-null    object
#  2   displacement  392 non-null    object
#  3   horsepower    392 non-null    object
#  4   weight        392 non-null    object
#  5   acceleration  392 non-null    object
#  6   model year    392 non-null    object
#  7   origin        392 non-null    object
#  8   car name      392 non-null    object
# dtypes: object(9)
# memory usage: 30.6+ KB

# %%
#colunas = ['mpg', 'cylinders',	'displacement',	'horsepower',	'weight',	'acceleration',	'model year',	'origin']
#for coluna in colunas:
#  df[coluna] = pd.to_numeric(df[coluna].str.replace(',', '.'))
df = df.apply(lambda x: x.str.replace(',','.'))

# %%
#colunas = ['mpg', 'cylinders',	'displacement',	'horsepower',	'weight',	'acceleration',	'model year',	'origin']
#for coluna in colunas:
#  df_copy[coluna] = pd.to_numeric(df_copy[coluna].str.replace(',', '.'))
df = df.apply(pd.to_numeric, errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    float64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    float64
#  7   origin        392 non-null    float64
#  8   car name      392 non-null    object
# dtypes: float64(8), object(1)
# memory usage: 30.6+ KB

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0        8.0         307.0       130.0  3504.0          12.0
# 1  15.0        8.0         350.0       165.0  3693.0          11.5
# 2  18.0        8.0         318.0       150.0  3436.0          11.0
# 3  16.0        8.0         304.0       150.0  3433.0          12.0
# 4  17.0        8.0         302.0       140.0  3449.0          10.5
#
#    model year  origin                   car name
# 0        70.0     1.0  chevrolet chevelle malibu
# 1        70.0     1.0          buick skylark 320
# 2        70.0     1.0         plymouth satellite
# 3        70.0     1.0              amc rebel sst
# 4        70.0     1.0                ford torino

# %%
df_agrupado_ano_mpg = df.groupby('model year')['mpg'].max()
df_agrupado_ano_mpg
# Out:
# model year
# 70.0    27.0
# 71.0    35.0
# 72.0    28.0
# 73.0    29.0
# 74.0    32.0
# 75.0    33.0
# 76.0    33.0
# 77.0    36.0
# 78.0    43.1
# 79.0    37.3
# 80.0    46.6
# 81.0    39.1
# 82.0    44.0
# Name: mpg, dtype: float64

# %%
type(df_agrupado_ano_mpg)
# Out:
# pandas.core.series.Series

# %%
ano_com_maior_economia = df_agrupado_ano_mpg.idxmax()
ano_com_maior_economia
# Out:
# 80.0

# %%
coluna = ['mpg']
df_agrupado = pd.DataFrame(df_agrupado_ano_mpg, columns = coluna).reset_index()
df_agrupado
# Out:
#     model year   mpg
# 0         70.0  27.0
# 1         71.0  35.0
# 2         72.0  28.0
# 3         73.0  29.0
# 4         74.0  32.0
# 5         75.0  33.0
# 6         76.0  33.0
# 7         77.0  36.0
# 8         78.0  43.1
# 9         79.0  37.3
# 10        80.0  46.6
# 11        81.0  39.1
# 12        82.0  44.0

# %%
type(df_agrupado)
# Out:
# pandas.core.frame.DataFrame

# %%
import matplotlib.pyplot as plt

plt.bar(df_agrupado['model year'], df_agrupado['mpg'])
# Out:
# <BarContainer object of 13 artists>

# %% [markdown]
# 5 - No intervalo interquartil, diga o valor para o 3º quartil da coluna "horsepower"

# %%
# Calculando o terceiro quartil (Q3)
df['horsepower'].quantile(0.75)
# Out:
# 840.0

# %%
df_copy['horsepower'].quantile(0.75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df_copy['horsepower'].quantile(0.75)
#
# NameError: name 'df_copy' is not defined

# %% [markdown]
# 6 -  Após a limpeza dos dados(dropar as linhas com valores nulos), quantos tipos de carros distintos nós temos em nossa base?

# %%
df['car name'].nunique()
# Out:
# 301

# %%
df_copy = pd.read_csv("auto-mpg-original.csv", sep=";")

# %%
df_copy['car name'].nunique()
# Out:
# 312

# %% [markdown]
# 7 - Qual o desvio padrão aproximado da coluna "mpg"?

# %%
df['mpg'].std()
# Out:
# 7.805007486571799

# %%
df['mpg'].mean()
# Out:
# 23.445918367346938

# %% [markdown]
# 8 - Qual o valor da correlação entre as colunas "cylinders" e "weight"? Obs: Considere o coeficiente de correlação de Pearson

# %%
df.corr( numeric_only=True).round(2)
# Out:
#                mpg  cylinders  displacement  horsepower  weight  acceleration  \
# mpg           1.00      -0.78          0.40        0.55   -0.83          0.42
# cylinders    -0.78       1.00         -0.24       -0.71    0.90         -0.50
# displacement  0.40      -0.24          1.00        0.08   -0.38          0.17
# horsepower    0.55      -0.71          0.08        1.00   -0.64          0.40
# weight       -0.83       0.90         -0.38       -0.64    1.00         -0.42
# acceleration  0.42      -0.50          0.17        0.40   -0.42          1.00
# model year    0.58      -0.35          0.01        0.22   -0.31          0.29
# origin        0.57      -0.57          0.37        0.35   -0.59          0.21
#
#               model year  origin
# mpg                 0.58    0.57
# cylinders          -0.35   -0.57
# displacement        0.01    0.37
# horsepower          0.22    0.35
# weight             -0.31   -0.59
# acceleration        0.29    0.21
# ...

# %% [markdown]
# 9 -  Qual a função nativa do pandas que modifica o tipo de dado um uma coluna do dataframe?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    float64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    float64
#  7   origin        392 non-null    float64
#  8   car name      392 non-null    object
# dtypes: float64(8), object(1)
# memory usage: 30.6+ KB

# %%
df['origin'] = df['origin'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    float64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    float64
#  7   origin        392 non-null    int32
#  8   car name      392 non-null    object
# dtypes: float64(7), int32(1), object(1)
# memory usage: 29.1+ KB

# %% [markdown]
# 10 - O z-score é uma métrica estatística fundamental para análise de dados, e sua equação é dada abaixo. Qual o significado do z-score?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Verificar o quão distante em desvios padrões os dados estão em relação à média.

# %% [markdown]
# 11 - Quando fazemos a correlação da variáveis, os valores negativos representam o que?

# %% [markdown]
# A relação das variáveis são inversamente proporcionais

# %%
plt.scatter(df['weight'], df['horsepower']) # correlação negativa

# %%
plt.scatter(df['weight'], df['cylinders']) #correlação positiva

# %% [markdown]
# 14 - Muitas das vezes quando precisamos entender a tendencia de como está sendo a evolução dos carros analisados, utilizamos um determinado tipo de gráfico. Qual gráfico utilizamos?

# %%
plt.plot(df_agrupado['model year'], df_agrupado['mpg'])

# %% [markdown]
# 15 - Observando o gráfico abaixo, qual das qual das cilindradas há a maior economia de combustível?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4ª

# %% [markdown]
# 16 - .Olhando para o código em python, o que está sendo codado em nosso notebook?
#
# ![image.png](data:image/png;base64,...)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    float64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    float64
#  7   origin        392 non-null    int32
#  8   car name      392 non-null    object
# dtypes: float64(7), int32(1), object(1)
# memory usage: 29.1+ KB

# %%
plt.figure(figsize=(24,20))

plt.subplot(4, 2, 1)
fig = df['mpg'].hist(bins=20)
fig.set_xlabel('mpg')
fig.set_ylabel('Número de casos')

plt.subplot(4, 2, 2)
fig = df['cylinders'].hist(bins=20)
fig.set_xlabel('cylinders')
fig.set_ylabel('Número de casos')

plt.subplot(4, 2, 3)
fig = df['displacement'].hist(bins=20)
fig.set_xlabel('displacement')
fig.set_ylabel('Número de casos')

plt.subplot(4, 2, 4)
fig = df['horsepower'].hist(bins=20)
fig.set_xlabel('horsepower')
fig.set_ylabel('Número de casos')

plt.subplot(4, 2, 5)
fig = df['weight'].hist(bins=20)
fig.set_xlabel('weight')
fig.set_ylabel('Número de casos')

plt.subplot(4, 2, 6)
fig = df['acceleration'].hist(bins=20)
fig.set_xlabel('acceleration')
fig.set_ylabel('Número de casos')

plt.subplot(4, 2, 7)
fig = df['model year'].hist(bins=20)
fig.set_xlabel('model year')
fig.set_ylabel('Número de casos')

plt.subplot(4, 2, 8)
fig = df['origin'].hist(bins=20)
fig.set_xlabel('origin')
fig.set_ylabel('Número de casos')
# Out:
# Text(0, 0.5, 'Número de casos')

# %% [markdown]
# Construção de gráficos de
# barras

# %% [markdown]
# 17 - No python, se quiser colocar uma coluna a mais para dentro do dataframe e adicionar o nome do país nesta coluna, como fazer?

# %%
set(df['origin'])
# Out:
# {1, 2, 3}

# %%
df['cod_pais'] = df.origin.replace([1,2,3], ['EUA','Europa','Japão'])

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 401  27.0        4.0         140.0       860.0  2790.0          15.6
# 402  44.0        4.0         970.0       520.0  2130.0          24.6
# 403  32.0        4.0         135.0       840.0  2295.0          11.6
# 404  28.0        4.0         120.0       790.0  2625.0          18.6
# 405  31.0        4.0         119.0       820.0  2720.0          19.4
#
#      model year  origin         car name cod_pais
# 401        82.0       1  ford mustang gl      EUA
# 402        82.0       2        vw pickup   Europa
# 403        82.0       1    dodge rampage      EUA
# 404        82.0       1      ford ranger      EUA
# 405        82.0       1       chevy s-10      EUA

# %% [markdown]
# 18 - Qual a função nativa do pandas que faz a contagem distinta de valores em uma coluna ou no dataframe todo?

# %%
df['car name'].value_counts()
# Out:
# car name
# amc matador            5
# ford pinto             5
# toyota corolla         5
# toyota corona          4
# amc hornet             4
#                       ..
# buick skyhawk          1
# chevrolet monza 2+2    1
# ford mustang ii        1
# pontiac astro          1
# chevy s-10             1
# Name: count, Length: 301, dtype: int64

# %% [markdown]
# 19 - Dentro do nosso dataset, queremos saber quantos carros temos e iremos analisar. Quantos carros temos no nosso conjunto de dados?

# %%
df_copy = pd.read_csv("auto-mpg-original.csv", sep=';')

df_copy['car name'].nunique()
# Out:
# 312

# %% [markdown]
# 20 -  Qual a função do pandas que utilizamos para evitar que a o índice de um dataframe vire uma coluna após uma modificação?

# %%
coluna = ['mpg']
df_agrupado_2 = pd.DataFrame(df_agrupado_ano_mpg, columns = coluna).reset_index(drop=True)
df_agrupado_2
# Out:
#      mpg
# 0   27.0
# 1   35.0
# 2   28.0
# 3   29.0
# 4   32.0
# 5   33.0
# 6   33.0
# 7   36.0
# 8   43.1
# 9   37.3
# 10  46.6
# 11  39.1
# 12  44.0
